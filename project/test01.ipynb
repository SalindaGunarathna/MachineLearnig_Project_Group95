# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("student-por.csv")

df = data.copy()

# %%
df.sample(5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 610     MS   F   19       R     GT3       A     1     1  at_home   at_home
# 416     GP   M   17       U     LE3       A     3     2    other     other
# 172     GP   M   16       U     GT3       T     3     3    other  services
# 211     GP   M   16       R     LE3       T     3     3  teacher     other
# 324     GP   M   18       U     GT3       T     1     2  at_home     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 610  ...      3        5      4     1     4      1        0   8   0   0
# 416  ...      4        4      4     1     2      5       10  16  18  18
# 172  ...      4        5      5     4     4      5        0  10  10   1
# 211  ...      3        3      4     3     5      3       16  10  11  12
# 324  ...      3        4      4     2     4      4       10  10  10  11
#
# [5 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df["school"].value_counts ()
# Out:
# school
# GP    423
# MS    226
# Name: count, dtype: int64

# %%
sns.countplot(x ="school",data= df)
# Out:
# <Axes: xlabel='school', ylabel='count'>

# %%
df["sex"].value_counts()
# Out:
# sex
# F    383
# M    266
# Name: count, dtype: int64

# %%
sns.countplot(x="sex",data =df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.distplot(df["age"])
# Out:
# C:\Users\kmwgs\AppData\Local\Temp\ipykernel_22760\316555093.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["age"])
# <Axes: xlabel='age', ylabel='Density'>

# %%
df["age"].plot.hist(bins =30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["address"].value_counts()
# Out:
# address
# U    452
# R    197
# Name: count, dtype: int64

# %%
sns.countplot(x= "address", data=df)
# Out:
# <Axes: xlabel='address', ylabel='count'>

# %%
df["famsize"].value_counts()
# Out:
# famsize
# GT3    457
# LE3    192
# Name: count, dtype: int64

# %%
sns.countplot(x ="famsize", data =df)
# Out:
# <Axes: xlabel='famsize', ylabel='count'>

# %%
df["Pstatus"].value_counts()
# Out:
# Pstatus
# T    569
# A     80
# Name: count, dtype: int64

# %%
sns.countplot(x="Pstatus",data = df)
# Out:
# <Axes: xlabel='Pstatus', ylabel='count'>

# %%
df["Medu"].value_counts()
# Out:
# Medu
# 2    186
# 4    175
# 1    143
# 3    139
# 0      6
# Name: count, dtype: int64

# %%
sns.countplot(x ="Medu",data = df)
# Out:
# <Axes: xlabel='Medu', ylabel='count'>

# %%
sns.distplot(df["Medu"])
# Out:
# C:\Users\kmwgs\AppData\Local\Temp\ipykernel_22760\1041029927.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Medu"])
# <Axes: xlabel='Medu', ylabel='Density'>

# %%
sns.boxplot(df["age"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["absences"])
# Out:
# <Axes: >

# %%
df["absences"] = np.log1p(df["absences"])

# %%
sns.boxplot(df["absences"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["G1"])
# Out:
# <Axes: >

# %%
df["G1"] = np.log1p(df["G1"])

# %%
sns.boxplot(df["G1"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["G2"])
# Out:
# <Axes: >

# %%
df["G2"] = np.log1p(df["G2"])
sns.boxplot(df["G2"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["G3"])
# Out:
# <Axes: >

# %%
df["G3"] = np.log1p(df["G3"])
sns.boxplot(df["G3"])
# Out:
# <Axes: >

# %%
sns.distplot(data["G1"])
# Out:
# C:\Users\kmwgs\AppData\Local\Temp\ipykernel_22760\3782226016.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["G1"])
# <Axes: xlabel='G1', ylabel='Density'>

# %%
sns.distplot(df["G1"])
# Out:
# C:\Users\kmwgs\AppData\Local\Temp\ipykernel_22760\119306163.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["G1"])
# <Axes: xlabel='G1', ylabel='Density'>

# %%
sns.distplot(df["G2"])
# Out:
# C:\Users\kmwgs\AppData\Local\Temp\ipykernel_22760\3376494573.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["G2"])
# <Axes: xlabel='G2', ylabel='Density'>

# %%
sns.distplot (data["G2"])
# Out:
# C:\Users\kmwgs\AppData\Local\Temp\ipykernel_22760\3956282767.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot (data["G2"])
# <Axes: xlabel='G2', ylabel='Density'>

# %%
sns.distplot(df["G3"])
# Out:
# C:\Users\kmwgs\AppData\Local\Temp\ipykernel_22760\1622934455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["G3"])
# <Axes: xlabel='G3', ylabel='Density'>

# %%
sns.heatmap(data = df.isnull())
# Out:
# <Axes: >
